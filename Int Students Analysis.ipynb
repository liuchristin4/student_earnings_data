# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
grad_student_df = pd.read_excel("~/Desktop/Competition Data and Guidelines/1.Graduate Earning.csv", sheet_name = None)
education_exp_df = pd.read_excel("~/Desktop/Competition Data and Guidelines/2.Expenditure on Education.csv", sheet_name = None)
econ_growth_df = pd.read_excel("~/Desktop/Competition Data and Guidelines/3.Economic Growth.csv", sheet_name = None)
enrol_prov_df = pd.read_excel("~/Desktop/Competition Data and Guidelines/4.Enrollment By Prov.csv", sheet_name = None)
enrol_prgm_df = pd.read_excel("~/Desktop/Competition Data and Guidelines/5.Enrollment by Prgm.csv", sheet_name = None)
grads_year_df = pd.read_excel("~/Desktop/Competition Data and Guidelines/6.Grads By Year.csv", sheet_name = None)
tuition_prov_df = pd.read_excel("~/Desktop/Competition Data and Guidelines/7.Tuition By Province and Program.csv", sheet_name = None)
perm_res_df = pd.read_excel("~/Desktop/Competition Data and Guidelines/8.Perm App Res by Country.csv", sheet_name = None)
conv_country_df = pd.read_excel("~/Desktop/Competition Data and Guidelines/9.Conversion by Country.csv", sheet_name = None)

# %%
grad_student_df.describe()
# Out:
#        Graduate Earnings($)
# count             36.000000
# mean           52663.888889
# std            17429.271811
# min            24000.000000
# 25%            40600.000000
# 50%            50500.000000
# 75%            65250.000000
# max            96000.000000

# %%
grad_student_df.groupby(["LEVEL", "Percentile"]).agg("mean")
# Out:
#                             Graduate Earnings($)
# LEVEL      Percentile
# Bachelor's 25th percentile          35900.000000
#            75th percentile          57533.333333
#            Median                   45666.666667
# College    25th percentile          28233.333333
#            75th percentile          46766.666667
#            Median                   35933.333333
# Doctorate  25th percentile          49500.000000
#            75th percentile          81833.333333
#            Median                   65366.666667
# Master's   25th percentile          47266.666667
#            75th percentile          77300.000000
#            Median                   60666.666667

# %%
date_sorted = grad_student_df.sort_values("Ref_Date")
date_sorted[date_sorted["LEVEL"] == "Master's"].hist("Graduate Earnings($)")
plt.show()

# %%
college_students = date_sorted[date_sorted["LEVEL"] == "College"]
plt.scatter(college_students["Ref_Date"].tolist(), college_students["Graduate Earnings($)"].tolist())
plt.show()

# %%
master_students = date_sorted[date_sorted["LEVEL"] == "Master's"]
plt.scatter(master_students["Ref_Date"].tolist(), master_students["Graduate Earnings($)"].tolist())
plt.show()

# %%
enrol_prov_df
# Out:
#        Ref_Date                        Geo       Level Registration status  \
# 0    2010-09-01  Newfoundland and Labrador  University   Full-time student
# 1    2010-09-01  Newfoundland and Labrador  University   Full-time student
# 2    2010-09-01  Newfoundland and Labrador  University   Full-time student
# 3    2010-09-01  Newfoundland and Labrador  University   Full-time student
# 4    2010-09-01  Newfoundland and Labrador  University   Full-time student
# 5    2010-09-01  Newfoundland and Labrador  University   Full-time student
# 6    2010-09-01  Newfoundland and Labrador  University   Part-time student
# 7    2010-09-01  Newfoundland and Labrador  University   Part-time student
# 8    2010-09-01  Newfoundland and Labrador  University   Part-time student
# 9    2010-09-01  Newfoundland and Labrador  University   Part-time student
# 10   2010-09-01  Newfoundland and Labrador  University   Part-time student
# 11   2010-09-01  Newfoundland and Labrador  University   Part-time student
# 12   2010-09-01  Newfoundland and Labrador     College   Full-time student
#
# 7           Males  International students               60
# 8         Females       Canadian students             2316
# 9         Females  International students               45
# 10    Sex unknown       Canadian students                3
# 11    Sex unknown  International students                0
# 12          Males       Canadian students             3654
# 13          Males  International students               30
# 14          Males            Not reported                0
# 15        Females       Canadian students             3516
# 16        Females  International students               21
# 17        Females            Not reported                0
# 18    Sex unknown       Canadian students                0
# 19    Sex unknown  International students                0
# 20          Males       Canadian students             1482
# 21          Males  International students                6
# 22          Males            Not reported                0
# 23        Females       Canadian students             1455
# 24        Females  International students                6
# 25        Females            Not reported                0
# 26    Sex unknown       Canadian students                0
# 27          Males       Canadian students             1227
# 28          Males  International students              159
# 29        Females       Canadian students             2058
# ...           ...                     ...              ...
# 1485      Females  International students             3048
# 1486      Females            Not reported                0
# 1487  Sex unknown       Canadian students                9
# 1488  Sex unknown  International students                3
# 1489        Males       Canadian students            19623
# 1490        Males  International students             1515
# 1491        Males            Not reported                0
# 1492      Females       Canadian students            29298
# 1493      Females  International students             1278
# 1494      Females            Not reported                3
# 1495  Sex unknown       Canadian students               75
# 1496  Sex unknown  International students                3
# 1497        Males       Canadian students              417
# 1498        Males  International students                3
# 1499        Males            Not reported                0
# 1500      Females       Canadian students              900
# 1501      Females  International students                0
# 1502      Females            Not reported                9
# 1503  Sex unknown       Canadian students                6
# 1504  Sex unknown  International students                0
# 1505  Sex unknown            Not reported               12
# 1506        Males       Canadian students              915
# 1507        Males  International students                0
# 1508        Males            Not reported               69
# 1509      Females       Canadian students             1443
# 1510      Females  International students                0
# 1511      Females            Not reported               63
# 1512  Sex unknown       Canadian students              117
# 1513  Sex unknown  International students                0
# 1514  Sex unknown            Not reported               45
#
# [1515 rows x 7 columns]

# %%
provincial_stats = enrol_prov_df.groupby(["Geo","Gender"]).agg({"Num of Students":"sum"})

# %%
tuition_program_df = enrol_prov_df.merge(tuition_prov_df, how = 'inner', left_on= ["Ref_Date","Geo"], right_on=["Ref_Date","GEO"]).drop_duplicates(subset = ["Program of Study","Gender","GEO"])

# %%
tuition_grouped = tuition_program_df.groupby(["Program of Study","Geo"]).agg({"Tuition":"mean"})

# %%
plotted = tuition_grouped.groupby("Geo").agg({"Tuition":"mean"}).sort_values("Tuition").reset_index()

plt.figure(figsize = (22,5))
plt.scatter(plotted["Geo"].tolist(), plotted["Tuition"].tolist(), c = 'teal')
plt.title("avg tuition by province")
plt.xlabel("province")
plt.ylabel("avg tuition")
plt.show()

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "http://www.dofactory.com/Images/sql-joins.png")
# Out:
# <img src="http://www.dofactory.com/Images/sql-joins.png"/>
